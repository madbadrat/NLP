# %% [markdown]
# 1) Прочитать текст
# 2) Сегментировать
# 3) Токенизировать
# 4) Вывести все пары: первый и второй токен является прилагательным или существительным и полное совпадение род число падеж
# 5) Выводить леммы

# %%
import nltk
from nltk import sent_tokenize, word_tokenize

import pymorphy3

nltk.download('punkt')
m = pymorphy3.MorphAnalyzer()

with open('Malavita.txt', 'r', encoding='utf8') as file:
    text = file.read()

print(text)
# Out:
# Они заняли дом среди ночи.
#
# Другая семья увидела бы в этом начало чего-то нового. Рассвет, с которого начнется вереница новых рассветов. Новая жизнь в новом городе. Редкий момент, который никак нельзя прожить в темноте.
#
# А вот семейство Блейков вселилось в дом тайком, стараясь не привлекать к себе внимания. Магги, мать, вошла в дом первой, на всякий случай громко стуча каблуками по крыльцу, чтобы прогнать крыс, если те были, прошла все комнаты насквозь и остановилась в погребе, который показался ей чистым и идеально влажным для того, чтобы там дозревал круг пармезана и стояли ящики кьянти. Фредерик, отец семейства, исходно недолюбливавший грызунов, предоставил жене свободу действий и обошел дом с карманным фонариком, потом вышел на веранду, где кучей были свалены ржавая садовая мебель, вздувшийся теннисный стол и прочие неразличимые во тьме предметы.
#
# ...

# %%
sent = sent_tokenize(text)
for i in range(len(sent)):
    print(sent[i] + "\n")
# Out:
# Они заняли дом среди ночи.
#
# Другая семья увидела бы в этом начало чего-то нового.
#
# Рассвет, с которого начнется вереница новых рассветов.
#
# Новая жизнь в новом городе.
#
# Редкий момент, который никак нельзя прожить в темноте.
#
# А вот семейство Блейков вселилось в дом тайком, стараясь не привлекать к себе внимания.
#
# Магги, мать, вошла в дом первой, на всякий случай громко стуча каблуками по крыльцу, чтобы прогнать крыс, если те были, прошла все комнаты насквозь и остановилась в погребе, который показался ей чистым и идеально влажным для того, чтобы там дозревал круг пармезана и стояли ящики кьянти.
#
# Фредерик, отец семейства, исходно недолюбливавший грызунов, предоставил жене свободу действий и обошел дом с карманным фонариком, потом вышел на веранду, где кучей были свалены ржавая садовая мебель, вздувшийся теннисный стол и прочие неразличимые во тьме предметы.
#
# ...

# %%
for i in range(len(sent)):
    words = word_tokenize(sent[i])
    print(words)
# Out:
# ['Они', 'заняли', 'дом', 'среди', 'ночи', '.']
# ['Другая', 'семья', 'увидела', 'бы', 'в', 'этом', 'начало', 'чего-то', 'нового', '.']
# ['Рассвет', ',', 'с', 'которого', 'начнется', 'вереница', 'новых', 'рассветов', '.']
# ['Новая', 'жизнь', 'в', 'новом', 'городе', '.']
# ['Редкий', 'момент', ',', 'который', 'никак', 'нельзя', 'прожить', 'в', 'темноте', '.']
# ['А', 'вот', 'семейство', 'Блейков', 'вселилось', 'в', 'дом', 'тайком', ',', 'стараясь', 'не', 'привлекать', 'к', 'себе', 'внимания', '.']
# ['Магги', ',', 'мать', ',', 'вошла', 'в', 'дом', 'первой', ',', 'на', 'всякий', 'случай', 'громко', 'стуча', 'каблуками', 'по', 'крыльцу', ',', 'чтобы', 'прогнать', 'крыс', ',', 'если', 'те', 'были', ',', 'прошла', 'все', 'комнаты', 'насквозь', 'и', 'остановилась', 'в', 'погребе', ',', 'который', 'показался', 'ей', 'чистым', 'и', 'идеально', 'влажным', 'для', 'того', ',', 'чтобы', 'там', 'дозревал', 'круг', 'пармезана', 'и', 'стояли', 'ящики', 'кьянти', '.']
# ...

# %%
for i in range(len(sent)):
    words = word_tokenize(sent[i])
    for j in range(len(words) - 1):
        currentWord = m.parse(words[j])[0]
        nextWord = m.parse(words[j + 1])[0]

        if (currentWord.tag.POS == "NOUN" and nextWord.tag.POS == "ADJF") or (
                currentWord.tag.POS == "ADJF" and nextWord.tag.POS == "NOUN"):
            if currentWord.tag.gender == nextWord.tag.gender:
                if currentWord.tag.number == nextWord.tag.number:
                    if currentWord.tag.case == nextWord.tag.case:
                        print(currentWord.normal_form + " " + nextWord.normal_form)
# Out:
# другой семья
# новый город
# карманный фонарик
# садовый мебель
# семнадцатилетний дочь
# правильный квадрат
# один присутствие
# типичный распорядок
# смежный комната
# телефонный линия
# компьютерный экран
# французский провинция
# тот сторона
# нормандский камень
# шахматный узор
# синий карниз
# юго-западный угол
# кованый железо
# затейливый дворец
# старый камень
# прежний дом
# единый слово
# резной доска
# каминный полка
# всякий предмет
# какой-нибудь предмет
# гнилой сарай
# мой страна
# новый удар
# стеклокерамический плита
# томатный соус
# красный дерево
# матовый абажур
# голый лампочка
# верный друг
# один уоррен
# тонкошёрстый псина
# поразительный неприметность
# жизненный совет
# спокойный совесть
# сам начало
# брезгливый вид
# ежедневный жизнь
# молчаливый стон
# весь день
# весь день
# скучный дискуссия
# дневный свет
# металлический скамейка
# крупный вязка
# тонкий запах
# сухой дерево
# пулемётный очередь
# этот груда
# гравиевый дорожка
# неизвестный семья
# ...
